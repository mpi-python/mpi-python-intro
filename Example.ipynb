# %%
print('hello')
# Out:
# hello

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b1946ac92492> in <module>()
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %% [markdown]
# print

# %%
j
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ddd5752b5fe6> in <module>()
# ----> 1 j
#
# NameError: name 'j' is not defined

# %% [markdown]
# __bold__ *italics* **bold**
