# %% [markdown]
# # Priming Experiment / by Limor Raviv
#
# This is my attempt of the final assignment.
# It's a mini version of a multimodal priming experiment, with images as primes and written ords as targets.
# I will try to collect RTs and accuracy scores and analyze the data

# %%
# make the stims
from IPython.display import display
from PIL import Image
import os 

os.chdir("C:/Users/limrav/mpi-python-intro/Session6/stims")

files = 'apple.bmp', 'banana.bmp', 'frog.bmp' , 'horse.bmp', 'rose.bmp' , 'sunflower.bmp'

pics=[]
pics_names=[]
words=[]

for name in files:
        pics.append(Image.open(name))
        word=str(name)
        word=word.replace(".bmp","")
        words.append(word)
        pics_names.append(word)

print(words)
print(pics_names)
display(*pics)
# Out:
# ['apple', 'banana', 'frog', 'horse', 'rose', 'sunflower']
# ['apple', 'banana', 'frog', 'horse', 'rose', 'sunflower']
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=300x300 at 0x263AFA53F98>
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=300x300 at 0x263AFA53A20>
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=300x300 at 0x263AFA38860>
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=300x300 at 0x263AFA670B8>
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=300x300 at 0x263AFA67048>
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=300x300 at 0x263AFA67198>

# %%
import subprocess as sp

sp.run(['python3', 'Experiment.py'],shell=True)
# Out:
# CompletedProcess(args=['python3', 'Experiment.py'], returncode=1)

# %%
# check why SaveData doesn't work

import SaveData
n=3
os.chdir("C:/Users/limrav/mpi-python-intro/Session6")
fileName = 'mylogfile.csv'  

SaveData.SaveData(n,pics_names[stims_pics[n]],words[stims_words[n]],str(0.5),1) 
# I don't know why this is not working.... fileName is defined in both the notebook and the function iteself...
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-51e520be8aa0> in <module>()
#       4 fileName = 'mylogfile.csv'
#       5
# ----> 6 SaveData.SaveData(n,pics_names[stims_pics[n]],words[stims_words[n]],str(0.5),1)
#       7 # I don't know why this is not working.... fileName is defined in both the notebook and the function iteself...
#
# ~\mpi-python-intro\Session6\SaveData.py in SaveData(trial, prime, target, RT, accuracy)
#       2 # function from https://discourse.psychopy.org/t/is-there-any-way-to-save-exp-data-after-every-trial/3173/2
#       3 def SaveData(trial,prime,target,RT,accuracy):
# ----> 4     # open file
#       5     import os
#       6     os.chdir("C:/Users/limrav/mpi-python-intro/Session6")
#
# NameError: name 'fileName' is not defined
