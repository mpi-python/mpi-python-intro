# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# Hello

# %%
Hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1d229271928d> in <module>()
# ----> 1 Hello
#
# NameError: name 'Hello' is not defined

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# c

# %% [markdown]
# lksdjfklsdj

# %%
kdjfdsk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-96d373cda258> in <module>()
# ----> 1 kdjfdsk
#
# NameError: name 'kdjfdsk' is not defined

# %%
print("*italics*")
# Out:
# *italics*

# %%
print(*italics*)
# Out:
#   File "<ipython-input-7-4fb71f31c2bb>", line 1
#     print(*italics*)
#                    ^
# SyntaxError: invalid syntax

# %%
print("a")

# %% [markdown]
# *italics*
